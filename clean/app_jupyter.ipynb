# %%
#hide
! [ -e /content ] && pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 81.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.4/492.4 kB 34.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 40.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 83.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 95.7 MB/s eta 0:00:00
# Mounted at /content/gdrive

# %%
from fastbook import *

# %% [markdown]
# # Appendix: Jupyter Notebook 101

# %% [markdown]
# ## Introduction

# %%
1+1
# Out:
# 2

# %% [markdown]
# ## Writing

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# ## Modes

# %% [markdown]
# ## Other Important Considerations

# %% [markdown]
# ## Markdown Formatting

# %% [markdown]
# ### Italics, Bold, Strikethrough, Inline, Blockquotes and Links

# %% [markdown]
# ### Headings

# %% [markdown]
# ### Lists

# %% [markdown]
# ## Code Capabilities

# %%
# Import necessary libraries
from fastai.vision.all import *
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
a = 1
b = a + 1
c = b + a + 1
d = c + b + a + 1
a, b, c ,d
# Out:
# (1, 2, 4, 8)

# %%
plt.plot([a,b,c,d])
plt.show()

# %%
Image.open(image_cat())
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=197x250>

# %% [markdown]
# ## Running the App Locally

# %% [markdown]
# ## Creating a Notebook

# %% [markdown]
# ## Shortcuts and Tricks

# %% [markdown]
# ### Command Mode Shortcuts

# %% [markdown]
# ### Cell Tricks

# %% [markdown]
# ### Line Magics

# %%
# %timeit [i+1 for i in range(1000)]
# Out:
# 59.7 µs ± 522 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
